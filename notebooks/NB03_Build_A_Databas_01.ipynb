# %% [markdown]
# These are the libraries you need to install:
#
# <div style="width:60%;font-size:0.85em">
#
# ```bash
# pip install pandas numpy lets-plot numerize tqdm sqlalchemy jupysql
# ```

# %%
import os
import sqlite3


import numpy as np
import pandas as pd

# %%
DATA_FOLDER = os.path.join('../data/')

RAW_FOLDER = os.path.join(DATA_FOLDER, 'raw')

# %%
#Puede faltar

# %%
conn = sqlite3.connect(os.path.join(DATA_FOLDER, 'football.db'))

# %% [markdown]
# ### Table 1: Teams

# %%
df_teams = pd.read_csv('../data/raw/text_full_final.csv')
df_teams_xg = pd.read_csv('../data/raw/team_xg.csv')

# %%
df_teams_xg['League'] = df_teams_xg['Leagues']
df_teams_xg = df_teams_xg.drop('Leagues', axis='columns')

# %%
df_teams = pd.merge(df_teams, df_teams_xg, on=['Teams', 'League'], how='inner')
df_teams

# %%
df_teams.info()

# %%
df_teams.to_sql('teams', conn, if_exists='replace', index=False)

# %%
pd.read_sql('SELECT * FROM teams LIMIT 10', conn)

# %% [markdown]
# ### Table 2: Players

# %%
df_players = pd.read_csv('../data/raw/players_data_full.csv')
df_player_xg = pd.read_csv('../data/raw/players_xg_data.csv')

# %%
df_players
# Out:
#              Player Name                                          Team Link  \
# 0             Harry Kane  https://www.whoscored.com/Teams/37/Show/German...
# 1        Jude Bellingham  https://www.whoscored.com/Teams/52/Show/Spain-...
# 2        Serhou Guirassy  https://www.whoscored.com/Teams/41/Show/German...
# 3          Kylian Mbappé  https://www.whoscored.com/Teams/304/Show/Franc...
# 4             Leroy Sané  https://www.whoscored.com/Teams/37/Show/German...
# ...                  ...                                                ...
# 1475     Norbert Gyömbér  https://www.whoscored.com/Teams/143/Show/Italy...
# 1476         Tiago Tomás  https://www.whoscored.com/Teams/33/Show/German...
# 1477       Isaac Success  https://www.whoscored.com/Teams/86/Show/Italy-...
# 1478  Moritz Broschinski  https://www.whoscored.com/Teams/109/Show/Germa...
# 1479       Ramon Terrats  https://www.whoscored.com/Teams/839/Show/Spain...
#
#       Minutes Played Goals This Season Assist This Season Shots PG  \
# 0               2844                36                  8      4.6
# 1               2324                19                  6      2.3
# 2               2214                28                  2      3.3
# 3               2160                27                  7      4.1
# 4               2142                 8                 11      2.7
# ...              ...               ...                ...      ...
# 1475            1763                 -                  -      0.2
# 1476            1031                 1                  1        1
# 1477             873                 1                  1      0.7
# 1478            1244                 2                  2        1
# 1479             782                 -                  2      0.4
#
#       Pass Success% Aerial Duels Won
# 0              73.6              0.9
# 1              89.8              0.9
# 2              81.4              2.3
# 3              85.2                -
# 4              84.4              0.1
# ...             ...              ...
# 1475           84.2              1.5
# 1476           71.0              0.6
# 1477           64.7                1
# 1478           63.0              1.4
# 1479           86.4              0.3
#
# [1480 rows x 8 columns]

# %%
df_player_xg
# Out:
#             Player Name  Expected Goals  \
# 0            Harry Kane           32.06
# 1       Jude Bellingham           11.70
# 2       Serhou Guirassy           22.14
# 3         Kylian Mbappé           19.93
# 4            Leroy Sané           10.25
# ..                  ...             ...
# 995    Pedro Chirivella            1.51
# 996         Raúl Albiol            0.30
# 997     Alfonso Pedraza            0.61
# 998      Gaëtan Laborde            7.42
# 999  Eric Choupo-Moting            5.27
#
#     Difference Between Goals And Expected Goals  \
# 0                                          3.94
# 1                                           7.3
# 2                                          5.86
# 3                                          7.07
# 4                                         -2.25
# ..                                          ...
# 995                                       -0.51
# 996                                        -0.3
# 997                                        0.39
# 998                                       -2.42
# 999                                       -3.27
#
#     Expected Goals For Every 90 Minutes  Total Shots  Aerial Duels Won
# 0                                  1.01          146              0.22
# 1                                  0.45           63              0.19
# 2                                   0.9           92              0.24
# 3                                  0.83          120              0.17
# 4                                  0.43           73              0.14
# ..                                  ...          ...               ...
# 995                                0.05           17              0.09
# 996                                0.01            6              0.05
# 997                                0.05            9              0.07
# 998                                0.35           64              0.12
# 999                                0.67           26              0.20
#
# [1000 rows x 6 columns]

# %%
df_players = pd.merge(df_players, df_player_xg, on=['Player Name'], how='inner') #LUEGO CAMBIAR
df_players.replace('-', 0, inplace=True)
df_players
# Out:
#              Player Name                                          Team Link  \
# 0             Harry Kane  https://www.whoscored.com/Teams/37/Show/German...
# 1        Jude Bellingham  https://www.whoscored.com/Teams/52/Show/Spain-...
# 2        Serhou Guirassy  https://www.whoscored.com/Teams/41/Show/German...
# 3          Kylian Mbappé  https://www.whoscored.com/Teams/304/Show/Franc...
# 4             Leroy Sané  https://www.whoscored.com/Teams/37/Show/German...
# ...                  ...                                                ...
# 1022         Raúl Albiol  https://www.whoscored.com/Teams/839/Show/Spain...
# 1023     Alfonso Pedraza  https://www.whoscored.com/Teams/839/Show/Spain...
# 1024      Gaëtan Laborde  https://www.whoscored.com/Teams/613/Show/Franc...
# 1025  Eric Choupo-Moting  https://www.whoscored.com/Teams/37/Show/German...
# 1026               Rodri  https://www.whoscored.com/Teams/54/Show/Spain-...
#
#       Minutes Played Goals This Season Assist This Season Shots PG  \
# 0               2844                36                  8      4.6
# 1               2324                19                  6      2.3
# 2               2214                28                  2      3.3
# 3               2160                27                  7      4.1
# 4               2142                 8                 11      2.7
# ...              ...               ...                ...      ...
# 1022            2036                 -                  1      0.2
# 1023            1120                 1                  3      0.5
# 1024            1914                 5                  2      1.9
# 1025             704                 2                  2        1
# 1026            1043                 -                  -      0.6
#
#       Pass Success% Aerial Duels Won_x  Expected Goals_x  \
# 0              73.6                0.9             32.06
# 1              89.8                0.9             11.70
# 2              81.4                2.3             22.14
# 3              85.2                  -             19.93
# 4              84.4                0.1             10.25
# ...             ...                ...               ...
# 1022           86.3                1.8              0.30
# 1023           78.9                0.3              0.61
# 1024           70.6                0.9              7.42
# 1025           84.1                0.6              5.27
# 1026           82.8                  -              4.46
#
#      Difference Between Goals And Expected Goals_x  \
# 0                                             3.94
# 1                                              7.3
# 2                                             5.86
# 3                                             7.07
# 4                                            -2.25
# ...                                            ...
# 1022                                          -0.3
# 1023                                          0.39
# 1024                                         -2.42
# 1025                                         -3.27
# 1026                                          3.54
#
#      Expected Goals For Every 90 Minutes_x  Total Shots_x  Aerial Duels Won_y  \
# 0                                     1.01            146                0.22
# 1                                     0.45             63                0.19
# 2                                      0.9             92                0.24
# 3                                     0.83            120                0.17
# 4                                     0.43             73                0.14
# ...                                    ...            ...                 ...
# 1022                                  0.01              6                0.05
# 1023                                  0.05              9                0.07
# 1024                                  0.35             64                0.12
# 1025                                  0.67             26                0.20
# 1026                                  0.14             62                0.07
#
#       Expected Goals_y Difference Between Goals And Expected Goals_y  \
# 0                32.06                                          3.94
# 1                11.70                                           7.3
# 2                22.14                                          5.86
# 3                19.93                                          7.07
# 4                10.25                                         -2.25
# ...                ...                                           ...
# 1022              0.30                                          -0.3
# 1023              0.61                                          0.39
# 1024              7.42                                         -2.42
# 1025              5.27                                         -3.27
# 1026              4.46                                          3.54
#
#      Expected Goals For Every 90 Minutes_y  Total Shots_y  Aerial Duels Won
# 0                                     1.01            146              0.22
# 1                                     0.45             63              0.19
# 2                                      0.9             92              0.24
# 3                                     0.83            120              0.17
# 4                                     0.43             73              0.14
# ...                                    ...            ...               ...
# 1022                                  0.01              6              0.05
# 1023                                  0.05              9              0.07
# 1024                                  0.35             64              0.12
# 1025                                  0.67             26              0.20
# 1026                                  0.14             62              0.07
#
# [1027 rows x 18 columns]
